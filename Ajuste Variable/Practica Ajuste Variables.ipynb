# %% [markdown]
# # Probabilidad y Estadística con Python

# %% [markdown]
# ## ¿Qué es la Estadística?
#
# La estadística suele ser definida como la ciencia de aprender de los datos o como la ciencia de obtener conclusiones en la presencia de incertidumbre. Se relaciona principalmente con la recolección, análisis e interpretación de datos, así como también con la efectiva comunicación y presentación de los resultados basados en esos datos. Como por datos entendemos a cualquier clase de información grabada, la estadística juego un rol importante en muchas disciplinas científicas.
#
# La estadística suele ser dividida en dos grandes ramas:
#
# La estadística descriptiva: La cual se dedica a recolectar, ordenar, analizar y representar a un conjunto de datos, con el fin de describir apropiadamente las características de este. Calcula los parámetros estadísticos que describen el conjunto estudiado. Algunas de las herramientas que utiliza son gráficos, medidas de frecuencias, medidas de centralización, medidas de posición, medidas de dispersión, entre otras.
#
# La estadistica inferencial: La cual estudia cómo sacar conclusiones generales para toda la población a partir del estudio de una muestra, y el grado de fiabilidad o significación de los resultados obtenidos. Sus principales herramientas son el muestreo, la estimación de parámetros y el contraste de hipótesis.

# %% [markdown]
# ## Conceptos básicos de la estadística descriptiva
#
# En *[estadística descriptiva](https://es.wikipedia.org/wiki/Estad%C3%ADstica_descriptiva)* se utilizan distintas medidas para intentar describir las propiedades de nuestros datos, algunos de los conceptos básicos, son:
#
# * **Media aritmética**: La [media aritmética](https://es.wikipedia.org/wiki/Media_aritm%C3%A9tica) es el valor obtenido al sumar todos los *[datos](https://es.wikipedia.org/wiki/Dato)* y dividir el resultado entre el número total elementos. Se suele representar con la letra griega $\mu$. Si tenemos una [muestra](https://es.wikipedia.org/wiki/Muestra_estad%C3%ADstica) de $n$ valores, $x_i$, la *media aritmética*, $\mu$, es la suma de los valores divididos por el numero de elementos; en otras palabras:
# $$\mu = \frac{1}{n} \sum_{i}x_i$$
#
#
# * **Desviación respecto a la media**: La desviación respecto a la media es la diferencia en valor absoluto entre cada valor de la variable estadística y la media aritmética.
# $$D_i = |x_i - \mu|$$
#
#
# * **Varianza**: La [varianza](https://es.wikipedia.org/wiki/Varianza) es la media aritmética del cuadrado de las desviaciones respecto a la media de una distribución estadística. La varianza intenta describir la dispersión de los *[datos](https://es.wikipedia.org/wiki/Dato)*. Se representa como $\sigma^2$.
# $$\sigma^2 = \frac{\sum\limits_{i=1}^n(x_i - \mu)^2}{n} $$
#
#
# * **Desviación típica**: La [desviación típica](https://es.wikipedia.org/wiki/Desviaci%C3%B3n_t%C3%ADpica) es la raíz cuadrada de la varianza. Se representa con la letra griega $\sigma$.
# $$\sigma = \sqrt{\frac{\sum\limits_{i=1}^n(x_i - \mu)^2}{n}} $$
#
#
# * **Moda**: La <a href="https://es.wikipedia.org/wiki/Moda_(estad%C3%ADstica)">moda</a> es el valor que tiene mayor frecuencia absoluta. Se representa con $M_0$
#
#
# * **Mediana**: La <a href="https://es.wikipedia.org/wiki/Mediana_(estad%C3%ADstica)">mediana</a> es el valor que ocupa el lugar central de todos los datos cuando éstos están ordenados de menor a mayor. Se representa con $\widetilde{x}$.

# %% [markdown]
# ### Ejemplos en Python
#
# Calcular los principales indicadores de la *[estadística descriptiva](https://es.wikipedia.org/wiki/Estad%C3%ADstica_descriptiva)* con [Python](http://python.org/) es muy fácil!.

# %%
# Ejemplos de estadistica descriptiva con python

import numpy as np # importando numpy
from scipy import stats # importando scipy.stats
import pandas as pd # importando pandas

np.random.seed(2131982) # para poder replicar el random

# %%
datos = np.random.randn(5, 4) # datos normalmente distribuidos
datos
# Out:
# array([[ 0.46038022, -1.08942528, -0.62681496, -0.63329028],
#        [-0.1074033 , -0.88138082, -0.34466623, -0.28320214],
#        [ 0.94051171,  0.86693793,  1.20947882, -0.16894118],
#        [-0.12790177, -0.58099931, -0.46188426, -0.18148302],
#        [-0.76959435, -1.37414587,  1.37696874, -0.18040537]])

# %%
# media arítmetica
datos.mean() # Calcula la media aritmetica de
# Out:
# -0.14786303590303568

# %%
np.mean(datos) # Mismo resultado desde la funcion de numpy
# Out:
# -0.14786303590303568

# %%
datos.mean(axis=1) # media aritmetica de cada fila
# Out:
# array([-0.47228757, -0.40416312,  0.71199682, -0.33806709, -0.23679421])

# %%
datos.mean(axis=0) # media aritmetica de cada columna
# Out:
# array([ 0.0791985 , -0.61180267,  0.23061642, -0.2894644 ])

# %%
# mediana
np.median(datos)
# Out:
# -0.23234258265023794

# %%
np.median(datos, 0) # media aritmetica de cada columna
# Out:
# array([-0.1074033 , -0.88138082, -0.34466623, -0.18148302])

# %%
 # Desviación típica
np.std(datos)
# Out:
# 0.73755354584071608

# %%
np.std(datos, 0) # Desviación típica de cada columna
# Out:
# array([ 0.58057213,  0.78352862,  0.87384108,  0.17682485])

# %%
# varianza
np.var(datos)
# Out:
# 0.54398523298221324

# %%
np.var(datos, 0) # varianza de cada columna
# Out:
# array([ 0.337064  ,  0.6139171 ,  0.76359823,  0.03126703])

# %%
# moda
stats.mode(datos) # Calcula la moda de cada columna
# el 2do array devuelve la frecuencia.
# Out:
# (array([[-0.76959435, -1.37414587, -0.62681496, -0.63329028]]),
#  array([[ 1.,  1.,  1.,  1.]]))

# %%
datos2 = np.array([1, 2, 3, 6, 6, 1, 2, 4, 2, 2, 6, 6, 8, 10, 6])
stats.mode(datos2) # aqui la moda es el 6 porque aparece 5 veces en el vector.
# Out:
# ModeResult(mode=array([6]), count=array([5]))

# %% [markdown]
# ## Practica :
# Generar un modelo que me permita simular el uso de recursos de los hospitales por cada una de las provincias, para ello obtener la informacion revisada en la practica de investigacion y tomar como ejemplo la practica de simulacion de atencion de paciente del COVID revisada en clase. Lo que se busca es poder generar graficos de uso de recursos:
#
# - Costos (Generar un aproximacion de cuanto se invierte para atender a un paciente con COVID)
# - Personal (Aproximacion del uso del personal por paciente, o el hospital)
# - Camas
# - Equipos/Insumos medicos (Obtener una aproximacion del uso de equipos medicos)
# - Pacientes (Informacion obtenida desde el ministerio de salud - validar con el porcentual del tipo de paciente [ninio 10%, adulto 30%, riesgo 60%]) - Hospitalizacion 80%, Otros 20%
#
#
# Para ello deberan generar un modelo lo mas cercano a la realidad, y con ayuda de la estadistica descriptiva ajustar los valores. Es importante tener como datos de entrada el dia y el numero de pacientes.
#
# Finalmente validar el modelo con lo la realidad del pais (Investigar en  base al tema el uso de los recursos publicos )

# %% [markdown]
# # Librerias

# %%
import simpy
import random
import matplotlib.pyplot as pp
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Datos de los Hospitales Provincia del Oro

# %%
#PARAMETROS
HOSPITALES = 2
#Numero de camas hospital Obstetrico Angela Loayza de Ollague
HOSPITAL_A_NUM_CAMAS = 158
#Numero de camas hospital General Tofilo Davila
HOSPITAL_B_NUM_CAMAS = 220
#Personal Medico hospital Obstetrico Angela Loayza de Ollague
HOSPITAL_A_NUM_PERSONAL = 280
#Personal Medico hospital General Tofilo Davila
HOSPITAL_B_NUM_PERSONAL = 345
#Equipos disponibles hospital Obstetrico Angela Loayza de Ollague
HOSPITAL_A_EQUIPOS = 26
#Equipos disponibles hospital General Tofilo Davila
HOSPITAL_B_EQUIPOS = 58
#Cantidad infectados en la provincia
INFECTADOS = 637
#MEDIANA
TASA_CRECIMIENTO = 56
#Equipos y personal de trabajo tiempo en dias estimado de uso.
DIAS_PERSONAL = 10
DIAS_EQUIPOS = 3
#Dias de internado de los pacientes
DIAS_INTERNADO = 10
#Dias en los que se basa la simulacion
DIAS_SIMULACION = 20
#Coto de atencion por persona
COSTO_POR_PERSONA=800


#Diccionario para almacenar los resultados
persona_recuperadas={}
persona_fallecidas={}
pacientes_ninos={}
pacientes_adultos={}
pacientes_ancianos={}
pacientes_con_equipos=[]
pacientes_con_camas=[]
pacientes_con_personalmedico=[]

# %% [markdown]
# # Simulacion

# %%
class Hospital(object):
    #constructor
    def __init__(self, env, num_cama,num_personal,num_equipos, name):
            self.env = env
            self.num_cama = num_cama
            self.num_personal=num_personal
            self.num_equipos=num_equipos
            self.camas = simpy.Resource(env, num_cama)
            self.personal = simpy.Resource(env, num_personal)
            self.equipos = simpy.Resource(env, num_equipos)
            self.name = name
            
    def ingresar_paciente(self, paciente):
        yield self.env.timeout(random.randint(DIAS_INTERNADO-5, DIAS_INTERNADO+5))
        print("Ingreso paciente: ", paciente, " en: ", self.env.now, " hospital ", self.name)
    def personal_paciente(self, paciente):
        yield self.env.timeout(random.randint(DIAS_PERSONAL-3, DIAS_PERSONAL+3))
        print("Personal al asignado al pacinte: ", paciente, " en: ", self.env.now, " hospital ", self.name)
    def equipos_paciente(self, paciente):
        yield self.env.timeout(random.randint(DIAS_EQUIPOS-1, DIAS_EQUIPOS+1))
        print("Equipo para el paciente: ", paciente, " en: ", self.env.now, " hospital ", self.name)
        
def llegada_paciente(env, hospital, paciente):
    arrive = env.now
    estado = random.randint(1,100)
    if (estado <= 10 and estado > 0):
        pacientes_ninos[env.now] = pacientes_ninos[env.now] + 1 if env.now in pacientes_ninos else  1
        
        with hospital.camas.request() as cama:
            dias_esperando = random.randint(1,1) #Numero de dias maximo que puede esperar sin ser asignado a una cama dentro del hospital
            requerimiento = yield cama | env.timeout(dias_esperando) #Asignar un tiempo de espera
            wait = env.now - arrive
            if cama in requerimiento:
                print("Paciente: ", paciente, "entro a cama en el hospital " , hospital.name)
                yield env.process(hospital.ingresar_paciente(paciente))
                arrive2 = env.now
                pacientes_con_camas.append(1)
                with hospital.personal.request() as persona:
                    dias_esperando_personal = random.randint(1,2)
                    requerimiento2 = yield persona | env.timeout(dias_esperando_personal)
                    wait2 = env.now - arrive2
                    if persona in requerimiento2:
                        print("Paciente: ", paciente, " fue atendido en el " , hospital.name)
                        yield env.process(hospital.personal_paciente(paciente))
                        arrive3 = env.now
                        pacientes_con_personalmedico.append(1)
                        with hospital.equipos.request() as equipo:
                            dias_esperando_equipo = random.randint(1,2)
                            requerimiento3 = yield equipo | env.timeout(dias_esperando_equipo)
                            wait3 = env.now - arrive3
                            if equipo in requerimiento3:
                                print("Paciente: ", paciente, "uso equipos medicos del hospital " , hospital.name)
                                yield env.process(hospital.equipos_paciente(paciente))
                                estado = random.randint(1,100)
                                pacientes_con_equipos.append(1)
                                if (estado < 8) :
                                    persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                                else:
                                    persona_recuperadas[env.now] = persona_recuperadas[env.now] + 1 if env.now in persona_recuperadas else 1 
                            else:
                                print("Paciente " , paciente, "del hospital ", hospital.name, " espero", wait3 , " dias ---> Fallesio Por Falta de Equipos")
                                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
                    else:
                        print("Paciente " , paciente, " del hospital ", hospital.name, " espero ", wait2 , " dias ---> Fallecio por Falta de Personal")
                        persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
            else:
                print("Paciente " , paciente, "del hospital ", hospital.name, " espero ", wait , " dias ---> Fallecio por Falta de Camas")
                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1        
    
    if (estado <= 30 and estado >= 11):
        pacientes_adultos[env.now] = pacientes_adultos[env.now] + 1 if env.now in pacientes_adultos else  1
        
        with hospital.camas.request() as cama:
            dias_esperando = random.randint(1,2) #Numero de dias maximo que puede esperar sin ser asignado a una cama dentro del hospital
            requerimiento = yield cama | env.timeout(dias_esperando) #Asignar un tiempo de espera
            wait = env.now - arrive
            if cama in requerimiento:
                print("Este paciente: ", paciente, "entro a una cama en el hospital " , hospital.name)
                yield env.process(hospital.ingresar_paciente(paciente))
                arrive2 = env.now
                pacientes_con_camas.append(1)
                with hospital.personal.request() as persona:
                    dias_esperando_personal = random.randint(1,2)
                    requerimiento2 = yield persona | env.timeout(dias_esperando_personal)
                    wait2 = env.now - arrive2
                    if persona in requerimiento2:
                        print("Este paciente: ", paciente, "tubo atencion del personal en el hospital " , hospital.name)
                        yield env.process(hospital.personal_paciente(paciente))
                        arrive3 = env.now
                        pacientes_con_personalmedico.append(1)
                        with hospital.equipos.request() as equipo:
                            dias_esperando_equipo = random.randint(1,2)
                            requerimiento3 = yield equipo | env.timeout(dias_esperando_equipo)
                            wait3 = env.now - arrive3
                            if equipo in requerimiento3:
                                print("Paciente: ", paciente, "uso equipos medicos en el hospital " , hospital.name)
                                yield env.process(hospital.equipos_paciente(paciente))
                                estado = random.randint(1,100)
                                pacientes_con_equipos.append(1)
                                if (estado < 8) :
                                    persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                                else:
                                    persona_recuperadas[env.now] = persona_recuperadas[env.now] + 1 if env.now in persona_recuperadas else 1 
                            else:
                                print("Paciente " , paciente, "del hospital ", hospital.name, " espero ", wait3 , " dias ---> Fallecio por falta de Equipos")
                                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
                    else:
                        print("Paciente " , paciente, " del hospital ", hospital.name, " espero ", wait2 , " dias ---> Fallecio por falta de Personal")
                        persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
            else:
                print("Paciente " , paciente, "del hospital ", hospital.name, " espero ", wait , " dias ---> Fallecio por Falta de Camas")
                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1        

        
        
        
        
    if (estado <= 100 and estado >= 31):
        pacientes_ancianos[env.now] = pacientes_ancianos[env.now] + 1 if env.now in pacientes_ancianos else  1
        
        with hospital.camas.request() as cama:
            dias_esperando = random.randint(1,1) #Numero de dias maximo que puede esperar sin ser asignado a una cama dentro del hospital
            requerimiento = yield cama | env.timeout(dias_esperando) #Asignar un tiempo de espera
            wait = env.now - arrive
            if cama in requerimiento:
                print("Este paciente: ", paciente, "entro a una cama en el hospital " , hospital.name)
                yield env.process(hospital.ingresar_paciente(paciente))
                arrive2 = env.now
                pacientes_con_camas.append(1)
                with hospital.personal.request() as persona:
                    dias_esperando_personal = random.randint(1,2)
                    requerimiento2 = yield persona | env.timeout(dias_esperando_personal)
                    wait2 = env.now - arrive2
                    if persona in requerimiento2:
                        print("Este paciente: ", paciente, " fue atendido por el personal en el hospital " , hospital.name)
                        yield env.process(hospital.personal_paciente(paciente))
                        arrive3 = env.now
                        pacientes_con_personalmedico.append(1)
                        with hospital.equipos.request() as equipo:
                            dias_esperando_equipo = random.randint(1,2)
                            requerimiento3 = yield equipo | env.timeout(dias_esperando_equipo)
                            wait3 = env.now - arrive3
                            if equipo in requerimiento3:
                                print("Este paciente: ", paciente, "uso equipos medicos del hospital " , hospital.name)
                                yield env.process(hospital.equipos_paciente(paciente))
                                estado = random.randint(1,100)
                                pacientes_con_equipos.append(1)
                                if (estado < 8) :
                                    persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                                else:
                                    persona_recuperadas[env.now] = persona_recuperadas[env.now] + 1 if env.now in persona_recuperadas else 1 
                            else:
                                print("Paciente " , paciente, "del hospital ", hospital.name, " espero ", wait3 , " dias ---> Fallecio por Falta de Equipos")
                                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
                    else:
                        print("Paciente " , paciente, " del hospital ", hospital.name, " espero ", wait2 , " dias ---> Fallecio por Falta de Personal")
                        persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
            else:
                print("Paciente " , paciente, " del hospital ", hospital.name, " espero ", wait , " dias ---> Fallecio por falta de Camas")
                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1        

        
        
def ejecutar(env, tasa_crecimiento, infectados):
    hospitalA = Hospital(env, HOSPITAL_A_NUM_CAMAS,HOSPITAL_A_NUM_PERSONAL,HOSPITAL_A_EQUIPOS, "Obstetrico Angela Loayza de Ollague")
    hospitalB = Hospital(env, HOSPITAL_B_NUM_CAMAS,HOSPITAL_B_NUM_PERSONAL,HOSPITAL_B_EQUIPOS, "General Tofilo Davila")
    for i in range(infectados):
        asignar_hospital(env, hospitalA, hospitalB, i)
    paciente = infectados
    while True:
        yield env.timeout(1)
        for i in range(tasa_crecimiento):
            paciente += 1
            asignar_hospital(env, hospitalA, hospitalB, paciente)
                
def asignar_hospital(env, hospitalA, hospitalB, paciente):
    hosp_esc = random.randint(1,2)
    if (hosp_esc == 1):
        print("Entro nuevo paciente : ", paciente, " hospital Obstetrico Angela Loayza de Ollague tiempo ", env.now)
        env.process(llegada_paciente(env, hospitalA, paciente))
    else:
        print("Entro nuevo paciente : ", paciente, " hospital General Tofilo Davila tiempo ", env.now)
        env.process(llegada_paciente(env, hospitalB, paciente))
    
print("Estimado Simulacion del COVID 19")
env=simpy.Environment()
env.process(ejecutar(env,TASA_CRECIMIENTO, INFECTADOS))
env.run(until=DIAS_SIMULACION)

print("Resultados final de los pacientes :")
print("Pacientes que se recuperaron: ",persona_recuperadas)
print("Pacientes que fallecieron: ",persona_fallecidas)


datos=sorted(persona_recuperadas.items()) # Ordenamos los datos
x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
pp.plot(x,y,linewidth=2,color='red') # Dibujamos las lineas
pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
pp.title("Estimacion en Dias  -  Personas que se Recuperaron")
pp.grid(True) # Generamos una cuadricula
pp.show() # Mostramos el grafico

if (persona_fallecidas):
    datos=sorted(persona_fallecidas.items()) # Ordenamos los datos
    x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
    pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
    pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
    pp.title("Personas que fallecieron  -  Dias que se hospitalizaron")
    pp.grid(True) #Generamos una cuadricula
    pp.show() #Mostramos el grafico
if (pacientes_ninos):
    datos=sorted(pacientes_ninos.items()) # Ordenamos los datos
    x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
    pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
    pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
    pp.title("Pacientes que fueron Niños - Dias que se hospitalizaron")
    pp.grid(True) #Generamos una cuadricula
    pp.show() #Mostramos el grafico
if (pacientes_adultos):
    datos=sorted(pacientes_adultos.items()) # Ordenamos los datos
    x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
    pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
    pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
    pp.title("Pacientes que fueron Adutos  - Dias que se hospitalizaron")
    pp.grid(True) #Generamos una cuadricula
    pp.show() #Mostramos el grafico
if (pacientes_ancianos):
    datos=sorted(pacientes_ancianos.items()) # Ordenamos los datos
    x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
    pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
    pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
    pp.title("Pacientes que fueron Ancianos - Dias que se hospitalizaron")
    pp.grid(True) #Generamos una cuadricula
    pp.show() #Mostramos el grafico
# Out:
# Estimado Simulacion del COVID 19
# Entro nuevo paciente :  0  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  1  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  2  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  3  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  4  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  5  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  6  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  7  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  8  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  9  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  10  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  11  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  12  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  13  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  14  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  15  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  16  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  17  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  18  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  19  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  20  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  21  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  22  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  23  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  24  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  25  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  26  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  27  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  28  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  29  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  30  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  31  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  32  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  33  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  34  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  35  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  36  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  37  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  38  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  39  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  40  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  41  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  42  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  43  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  44  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  45  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  46  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  47  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  48  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  49  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  50  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  51  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  52  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  53  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  54  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  55  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  56  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  57  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  58  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  59  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  60  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  61  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  62  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  63  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  64  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  65  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  66  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  67  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  68  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  69  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  70  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  71  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  72  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  73  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  74  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  75  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  76  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  77  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  78  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  79  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  80  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  81  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  82  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  83  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  84  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  85  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  86  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  87  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  88  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  89  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  90  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  91  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  92  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  93  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  94  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  95  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  96  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  97  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  98  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  99  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  100  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  101  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  102  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  103  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  104  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  105  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  106  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  107  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  108  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  109  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  110  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  111  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  112  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  113  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  114  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  115  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  116  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  117  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  118  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  119  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  120  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  121  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  122  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  123  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  124  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  125  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  126  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  127  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  128  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  129  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  130  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  131  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  132  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  133  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  134  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  135  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  136  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  137  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  138  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  139  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  140  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  141  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  142  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  143  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  144  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  145  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  146  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  147  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  148  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  149  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  150  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  151  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  152  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  153  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  154  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  155  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  156  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  157  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  158  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  159  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  160  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  161  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  162  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  163  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  164  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  165  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  166  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  167  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  168  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  169  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  170  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  171  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  172  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  173  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  174  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  175  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  176  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  177  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  178  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  179  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  180  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  181  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  182  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  183  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  184  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  185  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  186  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  187  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  188  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  189  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  190  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  191  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  192  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  193  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  194  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  195  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  196  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  197  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  198  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  199  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  200  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  201  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  202  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  203  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  204  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  205  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  206  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  207  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  208  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  209  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  210  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  211  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  212  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  213  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  214  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  215  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  216  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  217  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  218  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  219  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  220  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  221  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  222  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  223  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  224  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  225  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  226  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  227  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  228  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  229  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  230  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  231  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  232  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  233  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  234  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  235  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  236  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  237  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  238  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  239  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  240  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  241  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  242  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  243  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  244  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  245  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  246  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  247  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  248  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  249  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  250  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  251  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  252  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  253  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  254  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  255  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  256  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  257  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  258  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  259  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  260  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  261  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  262  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  263  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  264  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  265  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  266  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  267  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  268  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  269  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  270  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  271  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  272  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  273  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  274  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  275  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  276  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  277  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  278  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  279  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  280  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  281  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  282  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  283  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  284  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  285  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  286  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  287  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  288  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  289  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  290  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  291  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  292  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  293  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  294  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  295  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  296  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  297  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  298  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  299  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  300  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  301  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  302  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  303  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  304  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  305  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  306  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  307  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  308  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  309  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  310  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  311  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  312  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  313  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  314  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  315  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  316  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  317  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  318  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  319  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  320  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  321  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  322  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  323  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  324  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  325  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  326  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  327  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  328  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  329  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  330  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  331  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  332  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  333  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  334  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  335  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  336  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  337  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  338  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  339  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  340  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  341  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  342  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  343  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  344  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  345  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  346  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  347  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  348  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  349  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  350  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  351  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  352  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  353  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  354  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  355  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  356  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  357  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  358  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  359  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  360  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  361  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  362  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  363  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  364  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  365  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  366  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  367  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  368  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  369  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  370  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  371  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  372  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  373  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  374  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  375  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  376  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  377  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  378  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  379  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  380  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  381  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  382  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  383  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  384  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  385  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  386  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  387  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  388  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  389  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  390  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  391  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  392  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  393  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  394  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  395  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  396  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  397  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  398  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  399  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  400  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  401  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  402  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  403  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  404  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  405  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  406  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  407  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  408  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  409  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  410  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  411  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  412  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  413  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  414  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  415  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  416  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  417  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  418  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  419  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  420  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  421  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  422  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  423  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  424  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  425  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  426  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  427  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  428  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  429  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  430  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  431  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  432  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  433  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  434  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  435  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  436  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  437  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  438  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  439  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  440  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  441  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  442  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  443  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  444  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  445  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  446  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  447  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  448  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  449  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  450  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  451  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  452  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  453  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  454  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  455  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  456  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  457  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  458  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  459  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  460  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  461  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  462  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  463  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  464  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  465  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  466  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  467  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  468  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  469  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  470  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  471  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  472  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  473  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  474  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  475  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  476  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  477  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  478  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  479  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  480  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  481  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  482  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  483  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  484  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  485  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  486  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  487  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  488  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  489  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  490  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  491  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  492  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  493  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  494  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  495  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  496  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  497  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  498  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  499  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  500  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  501  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  502  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  503  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  504  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  505  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  506  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  507  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  508  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  509  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  510  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  511  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  512  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  513  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  514  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  515  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  516  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  517  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  518  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  519  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  520  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  521  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  522  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  523  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  524  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  525  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  526  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  527  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  528  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  529  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  530  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  531  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  532  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  533  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  534  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  535  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  536  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  537  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  538  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  539  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  540  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  541  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  542  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  543  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  544  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  545  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  546  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  547  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  548  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  549  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  550  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  551  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  552  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  553  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  554  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  555  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  556  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  557  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  558  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  559  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  560  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  561  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  562  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  563  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  564  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  565  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  566  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  567  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  568  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  569  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  570  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  571  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  572  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  573  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  574  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  575  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  576  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  577  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  578  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  579  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  580  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  581  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  582  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  583  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  584  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  585  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  586  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  587  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  588  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  589  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  590  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  591  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  592  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  593  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  594  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  595  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  596  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  597  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  598  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  599  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  600  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  601  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  602  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  603  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  604  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  605  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  606  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  607  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  608  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  609  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  610  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  611  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  612  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  613  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  614  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  615  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  616  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  617  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  618  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  619  hospital Obstetrico Angela Loayza de Ollague tiempo  0
# Entro nuevo paciente :  620  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  621  hospital General Tofilo Davila tiempo  0
# Entro nuevo paciente :  622  hospital General Tofilo Davila tiempo  0
# ...
# Personal al asignado al pacinte:  109  en:  19  hospital  General Tofilo Davila
# Personal al asignado al pacinte:  168  en:  19  hospital  Obstetrico Angela Loayza de Ollague
# Personal al asignado al pacinte:  196  en:  19  hospital  Obstetrico Angela Loayza de Ollague
# Personal al asignado al pacinte:  203  en:  19  hospital  General Tofilo Davila
# Personal al asignado al pacinte:  301  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  75  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  66  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  10  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  162  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  44  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  73  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  146  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  123  en:  19  hospital  Obstetrico Angela Loayza de Ollague
# Equipo para el paciente:  262  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  278  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  132  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  187  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  212  en:  19  hospital  Obstetrico Angela Loayza de Ollague
# Equipo para el paciente:  95  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  227  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  32  en:  19  hospital  Obstetrico Angela Loayza de Ollague
# Equipo para el paciente:  192  en:  19  hospital  Obstetrico Angela Loayza de Ollague
# Equipo para el paciente:  211  en:  19  hospital  Obstetrico Angela Loayza de Ollague
# Equipo para el paciente:  261  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  265  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  272  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  69  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  359  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  378  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  405  en:  19  hospital  General Tofilo Davila
# Equipo para el paciente:  151  en:  19  hospital  Obstetrico Angela Loayza de Ollague
# Entro nuevo paciente :  1646  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1647  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1648  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1649  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1650  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1651  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1652  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1653  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1654  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1655  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1656  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1657  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1658  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1659  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1660  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1661  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1662  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1663  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1664  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1665  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1666  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1667  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1668  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1669  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1670  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1671  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1672  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1673  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1674  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1675  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1676  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1677  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1678  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1679  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1680  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1681  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1682  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1683  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1684  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1685  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1686  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1687  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1688  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1689  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1690  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1691  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1692  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1693  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1694  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1695  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1696  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1697  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1698  hospital Obstetrico Angela Loayza de Ollague tiempo  19
# Entro nuevo paciente :  1699  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1700  hospital General Tofilo Davila tiempo  19
# Entro nuevo paciente :  1701  hospital General Tofilo Davila tiempo  19
# Paciente  1594  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1597 del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por Falta de Camas
# Paciente  1598  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1599  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1607  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1609 del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por Falta de Camas
# Paciente  1610  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1614  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1615  del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1616  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1617  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1618  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1619  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1620 del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por Falta de Camas
# Paciente  1621  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1622  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1623 del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por Falta de Camas
# Paciente  1625  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1626  del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1628  del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1629 del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por Falta de Camas
# Paciente  1630 del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por Falta de Camas
# Paciente  1631  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1632  del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1633  del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1634  del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1635  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1636 del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por Falta de Camas
# Paciente  1637  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1638  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1639  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1640  del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1641  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1642  del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1644  del hospital  General Tofilo Davila  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  1645  del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Camas
# Paciente  19 del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por falta de Equipos
# Paciente  119 del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por Falta de Equipos
# Paciente  214 del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por Falta de Equipos
# Paciente  270 del hospital  Obstetrico Angela Loayza de Ollague  espero  1  dias ---> Fallecio por Falta de Equipos
# Paciente  289  del hospital  General Tofilo Davila  espero  19  dias ---> Fallecio por falta de Camas
# Paciente  370  del hospital  General Tofilo Davila  espero  19  dias ---> Fallecio por falta de Camas
# Paciente  169  del hospital  General Tofilo Davila  espero  19  dias ---> Fallecio por falta de Camas
# Este paciente:  228 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  129 uso equipos medicos del hospital  General Tofilo Davila
# Paciente:  208 uso equipos medicos en el hospital  General Tofilo Davila
# Este paciente:  397 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  92 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  105 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  259 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  1624 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  1627 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  411 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  1646 entro a una cama en el hospital  General Tofilo Davila
# Paciente:  90 uso equipos medicos en el hospital  General Tofilo Davila
# Este paciente:  1649 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  310 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  1650 entro a una cama en el hospital  General Tofilo Davila
# Paciente:  391 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  1651 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  127 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  1654 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  109 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  1659 entro a una cama en el hospital  General Tofilo Davila
# Paciente:  203 uso equipos medicos en el hospital  General Tofilo Davila
# Este paciente:  1665 entro a una cama en el hospital  General Tofilo Davila
# Paciente:  231 uso equipos medicos en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1600 entro a una cama en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  301 uso equipos medicos del hospital  General Tofilo Davila
# Este paciente:  1666 entro a una cama en el hospital  General Tofilo Davila
# Paciente:  1668 entro a cama en el hospital  General Tofilo Davila
# Este paciente:  1670 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  1673 entro a una cama en el hospital  General Tofilo Davila
# Paciente:  43 uso equipos medicos en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1604 entro a una cama en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1674 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  1677 entro a una cama en el hospital  General Tofilo Davila
# Paciente:  136 uso equipos medicos en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1612 entro a una cama en el hospital  Obstetrico Angela Loayza de Ollague
# Paciente:  177 uso equipos medicos en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1643 entro a una cama en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  189 uso equipos medicos del hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1647 entro a una cama en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1679 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  1680 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  1683 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  1685 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  1686 entro a una cama en el hospital  General Tofilo Davila
# Este paciente:  210 uso equipos medicos del hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1648 entro a una cama en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1652 entro a una cama en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1653 entro a una cama en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1655 entro a una cama en el hospital  Obstetrico Angela Loayza de Ollague
# Este paciente:  1656 entro a una cama en el hospital  Obstetrico Angela Loayza de Ollague
# Resultados final de los pacientes :
# Pacientes que se recuperaron:  {14: 2, 15: 3, 16: 10, 17: 17, 18: 16, 19: 25}
# Pacientes que fallecieron:  {1: 230, 2: 82, 3: 56, 4: 54, 5: 56, 6: 55, 7: 56, 8: 55, 9: 58, 10: 59, 11: 50, 12: 54, 13: 60, 14: 57, 15: 55, 16: 47, 17: 51, 18: 51, 19: 44}

# %% [markdown]
# # Resultado Estimado de Costos y Pacientes

# %%
Costo_Estimado_En_Camas=(sum(pacientes_con_camas)*(COSTO_POR_PERSONA-900))
Costo_Estimado_En_Personal=(sum(pacientes_con_personalmedico)*(COSTO_POR_PERSONA-500))
Costo_Estimado_En_Equipos=(sum(pacientes_con_equipos)*(COSTO_POR_PERSONA))
Total_Estimado_Costos=(Costo_Estimado_En_Camas+Costo_Estimado_En_Personal+Costo_Estimado_En_Equipos)
print("Resultados final de los pacientes :")
print("Pacientes que se recuperaron: ",persona_recuperadas)
print("Pacientes que fallecieron: ",persona_fallecidas)
print("Estimado del costo: ",Total_Estimado_Costos)

# %% [markdown]
# ## Conclusiones
#  En base a los resultados obtenidos se aprecia un costo bastante elevado en este caso devido que los dos hospitales de la provincia del oro cuentan con pocos equipos medicos para la atencion de sus pacientes, lo cual tambien muestra que una gran cantidad de personas esta falleciendo en la provincia. Por tanto la alta demanda de recursos no solo en esta provicica juega un factor importante como se demuestra en la simulacion.
#
# ## Recomendaciones
# Se recomienda usar los datos mas precisos que se logre optener ya que en mi caso estos centros medicos solo publicaban cierta informacion al publico, debido a que el numero de infectados es cada vez mas alto, ademas de no contar con mucho equipamiento y camas para atender a tantas personas. La informacion no es del todo exacta, no es informacion verificada debido a la situacion.
#
# ## Opiniones
# En mi opinion con forme a la investigacion realizada a los centros medicos, la falta de equipos, personal, camas y en algunos casos dinero para las prubas esta en contra de los ciudadanos, aun asi el gobierno no a respondido a esta falta de abastecimiento, no solo estos hopitales mencionados sino a nivel nacional. Por tanto deberia implemetar algun sistema de ayuda a estos hospitales que no son muy vistos en sus provincias ya que normalmente son pequeños.
